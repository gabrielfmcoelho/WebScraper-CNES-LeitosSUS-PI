# %%
print('VERIFICAÇÃO DE DEPENDENCIAS')
print('<><><><><><><><><><><><><><><><><><><>')
try:
    pip install -r requirements.txt
    pip install beautifulsoup4
    pip install requests
    print('')
except:
    print('')
print('<><><><><><><><><><><><><><><><><><><>')

# Importando bibliotecas
import pandas as pd
import requests
import urllib.request
import bs4
from bs4 import BeautifulSoup
import os
import time
from IPython.display import clear_output

def converter_comp_p_data(i):
    
    data = str(i)
    dia_ficcional = '20'
    ano_data = data[:4]
    mes_data = data[4:]
    data_completa = dia_ficcional + '/' + mes_data + '/' + ano_data 
    
    return data_completa

def converter_comp_p_ano(i):
    
    data = str(i)
    ano_data = data[:4]
    
    return int(ano_data)

def converter_comp_p_mes(i):
    
    data = str(i)
    mes_data = data[4:]
    
    return int(mes_data)

colunas_população = []
competencias = []
ano_inicial = 2016
ano_final = 2022
mes_inicial = 1
mes_final = 12
primeira_competencia = True
salvar_mun = False
contador_auxiliar = 1
index_mun = 0

dicionario_categorias = {'CIRÚRGICO':'Cirurgico',
                        'CLÍNICO':'Clinico',
                        'OBSTÉTRICO':'Obstetrico',
                        'PEDIATRICO':'Pediatrico',
                        'OUTRAS ESPECIALIDADES':'Outras Especialidades',
                        'HOSPITAL DIA':'Hospital Dia',
                        'COMPLEMENTAR':'Complementar'}

for ano_pop in range(ano_inicial, (ano_final+1)):
    colunas_população.append(f'População {ano_pop}')

nome_colunas_df = ['Competência', 'Ano', 'Mes', 'Código', 'Categoria', 'Descrição', 'Existente', 'SUS', '%Ocupação', 'Geocodigo', 'População']
nome_colunas_df_completo = nome_colunas_df + ['País', 'Estado', 'Município', 'Mesoregião', 'Regional de Saúde']

path_armazenamento_raiz = './Leitos_CNES_PI'
path_armazenamento_mun = path_armazenamento_raiz + '/Municipios'
path_auxiliar = './temp_WSS_CNES'
path_csv_munpi = 'MunicipiosPI.csv'

print('')
print('INICIANDO PROCEDIMENTO DE WEB SCRAPING')
print('Codigo preparado por Gabriel Coelho')
print('Me encontre em: https://www.linkedin.com/in/gabriel--coelho/')
print('<><><><><><><><><><><><><><><><><><><>')

print('')
print('...Criando diretorios')

try:
    os.makedirs(path_auxiliar)
    print('> Diretorio temporario criado')
except:
    print('> Diretorio temporario ja existente')
    
try:
    os.makedirs(path_armazenamento_mun)
    print('> Diretorio de armazenamento criado')
except:
    print('> Diretorio de armazenamento ja existente')

print('')
print('...Lendo dados')

try:
    df_municipios = pd.read_csv(path_csv_munpi)
    print('> Banco de dados dos municipios do Piaui 2016 a 2022 - OK')
except:
    print('> Banco de dados dos municipios do Piaui 2016 a 2022 - FALHOU')

try:
    df_Leitos_CNES_PI_Completo = pd.read_csv(f'{path_armazenamento_raiz}/Leitos_CNES_PI_Completo.csv')
    print('> Banco de dados dos leitos CNES PI - OK')
except:
    df_Leitos_CNES_PI_Completo = pd.DataFrame(columns=nome_colunas_df)
    df_Leitos_CNES_PI_Completo.to_csv(f'{path_armazenamento_raiz}/Leitos_CNES_PI_Completo.csv')
    print('> Banco de dados dos leitos CNES PI - Não existente -> Foi Criado')

try:
    df_pular_mun_lista = pd.read_csv(f'{path_auxiliar}/pular_mun_lista.csv')
    print('> Planilhar auxiliar detectada...lendo')
    print(df_pular_mun_lista['Geocodigo'].value_counts())
except:
    df_pular_mun_lista = pd.DataFrame(columns=['Geocodigo'])
    df_pular_mun_lista.to_csv(f'{path_auxiliar}/pular_mun_lista.csv')
    print('> Criando planilha auxiliar')

print('')
print('...Criando dados auxiliares')

municipios = list(df_municipios['Geocodigo'])
nome_município = list(df_municipios['Município'])
dicionario_municipios = dict(zip(municipios, nome_município))

try:
    for mun in municipios:
        for i in range(ano_inicial, (ano_final+1)):
            for j in range(mes_inicial, (mes_final+1)):
                if len(str(j)) < 2:
                    mes = f'0{j}'
                else:
                    mes = j
                ano = f'{i}{mes}'
                if primeira_competencia:
                    competencias.append(ano)
                for key, value in dicionario_municipios.items():
                    if (mun == key):
                        nome_mun = value
                        nome_mun = nome_mun.replace(' ','_')
                nome_dataframe = f'df_Leitos_CNES_PI_{nome_mun}_{ano}'
                vars()[nome_dataframe] = pd.DataFrame(columns=nome_colunas_df)
        primeira_competencia=False
    print('> Competencias e planilhas auxiliares - OK')
    print(f'> Inicio das competencias: {min(competencias)}, final das competencias: {max(competencias)}')
except:
    print(print('> Competencias e planilhas auxiliares - FALHOU'))
    
print('')
print('...Analisando dados dos municipios')

for mun in municipios:
    #try:
        pular_mun=False
        
        for key, value in dicionario_municipios.items():
            if (mun == key):
                nome_mun = value
                nome_mun = nome_mun.replace(' ','_')

                
        if(pular_mun):
            continue
        
        print('')
        print(f'...Iniciando {mun} - {nome_mun}: {index_mun+1}/224')
        print('---------------------------------')
        contador_auxiliar = contador_auxiliar + 1
        
        for i in competencias:
            #try:
                
                index_atual=0
                ultimo_titulo=''
                pular_proxima_linha=False
                primeiro=True
                controlador=True
        
                informações = ['','','','','','','','','','','']
                
                for index, row in df_pular_mun_lista.iterrows(): 
                    if(row['Geocodigo'] == mun):
                        #print(f'>> Pulando {nome_mun} - {i}')
                        pular_mun = True
                        index_atual = index_atual+1
                        break
                
                if(pular_mun):
                    continue
            
                print('')
                print(f'...Iniciando {nome_mun} - {i}:')
                
                try:
                    print('> Carregando pagina')
                    url = f'http://cnes2.datasus.gov.br/Mod_Ind_Tipo_Leito.asp?VEstado=22&VMun={mun}&VComp={i}'
                    pagina = urllib.request.urlopen(url)
                    soup = BeautifulSoup(pagina, 'html.parser')
                    tabela_bruta = soup.find_all('table')
                    tabela_filtrada = tabela_bruta[0].find('table', border=1, width=500, cellpadding=1, align='center')
                    print('>> Pagina carregada')
                except:
                    print('!!!!Problema ao explorar html!!!!  Tentando novamente..' )
                    url = f'http://cnes2.datasus.gov.br/Mod_Ind_Tipo_Leito.asp?VEstado=22&VMun={mun}&VComp={i}'
                    pagina = urllib.request.urlopen(url)
                    soup = BeautifulSoup(pagina, 'html.parser')
                    tabela_bruta = soup.find_all('table')
                    tabela_filtrada = tabela_bruta[0].find('table', border=1, width=500, cellpadding=1, align='center')
                    print('>> Pagina carregada')
            
                print('> Explorando a pagina')
                if (type(tabela_filtrada) == bs4.element.Tag):
                    for linha in tabela_filtrada.find_all('tr'):
        
                        if (not primeiro):
                            primeiro=True
                            continue
        
                        if (pular_proxima_linha):
                            pular_proxima_linha = (not pular_proxima_linha)
                            continue

                        titulo_raw = linha.find('td', colspan=3)
                        
                        if((type(titulo_raw) == bs4.element.Tag) and titulo_raw.text.strip() != ultimo_titulo):
                            titulo = titulo_raw.text.strip()
                            if(titulo != ultimo_titulo):
                                ultimo_titulo = titulo
                                pular_proxima_linha=True
                                if(controlador):
                                    controlador = False
                                else:
                                    primeiro = False
                                continue

                        dados = linha.find_all('td')

                        if len(dados) > 4:
                            break
                            
                        print('>> Carregando informações')
                        informações[0] = converter_comp_p_data(i)
                        informações[1] = converter_comp_p_ano(i)
                        informações[2] = converter_comp_p_mes(i)
                        informações[3] = int(dados[0].text.strip())
                        informações[4] = ultimo_titulo
                        informações[5] = dados[1].text.strip()
                        informações[6] = int(dados[2].text.strip())
                        informações[7] = int(dados[3].text.strip())
                        informações[8] = round(float((informações[7])/float(informações[6])), 2)
                        informações[9] = mun
                        informações[10] = '0'

                        df_informações = pd.DataFrame([informações], columns=nome_colunas_df)
                        vars()[f'df_Leitos_CNES_PI_{nome_mun}_{i}'] = pd.concat([vars()[f'df_Leitos_CNES_PI_{nome_mun}_{i}'], df_informações], ignore_index=True)
                        index_atual = index_atual+1
                    
                    vars()[f'df_Leitos_CNES_PI_{nome_mun}_{i}']['Competência'] = pd.to_datetime(vars()[f'df_Leitos_CNES_PI_{nome_mun}_{i}']['Competência'], format='%d/%m/%Y')

                    vars()[f'df_Leitos_CNES_PI_{nome_mun}_{i}']['Categoria'] = vars()[f'df_Leitos_CNES_PI_{nome_mun}_{i}']['Categoria'].map(dicionario_categorias)
            
                    
                    print('>>> Merge com dados do municipio')
                    vars()[f'df_Leitos_CNES_PI_{nome_mun}_{i}'] = pd.merge(vars()[f'df_Leitos_CNES_PI_{nome_mun}_{i}'], df_municipios, on="Geocodigo", how="left", suffixes=('_x', '_y'))
                    
                    print('>>> Identificando total populacional do periodo')
                    for index, row in vars()[f'df_Leitos_CNES_PI_{nome_mun}_{i}'].iterrows():
                        for pop_ano in range(ano_inicial, (ano_final+1)):
                            if (row['Ano'] == pop_ano):
                                for index_mun_i, row_mun_i in df_municipios.iterrows():
                                    if(row['Geocodigo'] == row_mun_i['Geocodigo']):
                                        vars()[f'df_Leitos_CNES_PI_{nome_mun}_{i}'].iloc[index,10] = df_municipios[f'População {pop_ano}'][index_mun_i]
                                        break
                            else:
                                continue
                            break

                    vars()[f'df_Leitos_CNES_PI_{nome_mun}_{i}'].drop(colunas_população, axis=1, inplace=True)

                    #vars()[f'df_Leitos_CNES_PI_{nome_mun}_{i}'].reset_index(inplace=True, drop=True)
                    #df_Leitos_CNES_PI_Completo.reset_index(inplace=True, drop=True)
                    
                    print('>>> Adicionando à planilha completa')
                    df_Leitos_CNES_PI_Completo = pd.concat([df_Leitos_CNES_PI_Completo, vars()[f'df_Leitos_CNES_PI_{nome_mun}_{i}']], ignore_index=True)
                    
                    if salvar_mun:
                        print('>>> Salvando planilha especifica')
                        
                        vars()[f'df_Leitos_CNES_PI_{nome_mun}_{i}'].to_csv(f'./Leitos_CNES_PI/Municipios/Leitos_CNES_PI_{nome_mun}_{i}.csv')

                    print(f'Dataset: {nome_mun} - {converter_comp_p_mes(i)}/{converter_comp_p_ano(i)} - OK')
                    #clear_output(wait=True)
                    
                else:
                    print('>> Exploração abortada')
                    print(f'Dataset: {nome_mun} - {converter_comp_p_mes(i)}/{converter_comp_p_ano(i)} - VAZIO')
                    #clear_output(wait=True)
                    
            
        print('---------------------------------')
        print('>> Salvando dados')
        df_mun = pd.DataFrame([mun], columns=['Geocodigo'])
        df_pular_mun_lista = pd.concat([df_pular_mun_lista, df_mun], ignore_index=True)
        df_pular_mun_lista = df_pular_mun_lista.loc[:,df_pular_mun_lista.columns.isin(['Geocodigo'])]
        df_pular_mun_lista.to_csv(f'{path_auxiliar}/pular_mun_lista.csv', index=False)
        df_Leitos_CNES_PI_Completo = df_Leitos_CNES_PI_Completo.loc[:,df_Leitos_CNES_PI_Completo.columns.isin(nome_colunas_df_completo)]
        df_Leitos_CNES_PI_Completo.sort_values(['Ano', 'Mes', 'Código', 'Geocodigo'],ascending = [True, True, True, True])
        df_Leitos_CNES_PI_Completo.to_csv(f'{path_armazenamento_raiz}/Leitos_CNES_PI_Completo.csv', index=False)
        index_mun = index_mun + 1
        print('>>> Dados salvos')
        print('')
        print('...Limpando terminal')
        clear_output(wait=True)
        
            #except(e):
                #print(e)
                #print(f'Dataset: {nome_mun} - {converter_comp_p_mes(i)}/{converter_comp_p_ano(i)} - FALHOU')
            
    #except(e):
        #print(e)
        #print(f'Municipio: {nome_mun} - FALHOU')
        
print('... Finalizando')   
df_Leitos_CNES_PI_Completo.to_csv('./Leitos_CNES_PI/Leitos_CNES_PI_Completo.csv', index=False)

print('<><><><><><><><><><><><><><><><><><><>')

print('')
print('!!! Finalizado !!!')

print('')
print('...Vamos ver como é a forma do nosso banco de dados!')
print('')
print(df_Leitos_CNES_PI_Completo)

print('')
print('...Aqui está a descrição do banco de dados criado! Aproveite!')
print('')
df_Leitos_CNES_PI_Completo.info()
# Out:
# INICIANDO PROCEDIMENTO DE WEB SCRAPING
# Codigo preparado por Gabriel Coelho
# Me encontre em: https://www.linkedin.com/in/gabriel--coelho/
# <><><><><><><><><><><><><><><><><><><>
#
# ...Criando diretorios
# > Diretorio temporario ja existente
# > Diretorio de armazenamento ja existente
#
# ...Lendo dados
# > Banco de dados dos municipios do Piaui 2016 a 2022 - OK
# > Banco de dados dos leitos CNES PI - OK
# > Planilhar auxiliar detectada...lendo
# 220005    7
# 220020    7
# 220025    7
# 220010    7
# 220027    6
#          ..
# 220793    1
# 220790    1
# 220785    1
# 220780    1
# 221070    1
# Name: Geocodigo, Length: 210, dtype: int64
#
# ...Criando dados auxiliares
# > Competencias e planilhas auxiliares - OK
# > Inicio das competencias: 201601, final das competencias: 202212
#
# ...Analisando dados dos municipios
#
# ...Iniciando 220005 - Acauã: 1/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220010 - Agricolândia: 2/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220020 - Água_Branca: 3/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220025 - Alagoinha_do_Piauí: 4/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220027 - Alegrete_do_Piauí: 5/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220030 - Alto_Longá: 6/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220040 - Altos: 7/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220045 - Alvorada_do_Gurguéia: 8/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220050 - Amarante: 9/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220060 - Angical_do_Piauí: 10/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220070 - Anísio_de_Abreu: 11/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220080 - Antônio_Almeida: 12/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220090 - Aroazes: 13/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220095 - Aroeiras_do_Itaim: 14/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220100 - Arraial: 15/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220105 - Assunção_do_Piauí: 16/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220110 - Avelino_Lopes: 17/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220115 - Baixa_Grande_do_Ribeiro: 18/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220117 - Barra_D'Alcântara: 19/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220120 - Barras: 20/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220130 - Barreiras_do_Piauí: 21/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220140 - Barro_Duro: 22/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220150 - Batalha: 23/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220155 - Bela_Vista_do_Piauí: 24/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220157 - Belém_do_Piauí: 25/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220160 - Beneditinos: 26/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220170 - Bertolínia: 27/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220173 - Betânia_do_Piauí: 28/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220177 - Boa_Hora: 29/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220180 - Bocaina: 30/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220190 - Bom_Jesus: 31/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220191 - Bom_Princípio_do_Piauí: 32/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220192 - Bonfim_do_Piauí: 33/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220194 - Boqueirão_do_Piauí: 34/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220196 - Brasileira: 35/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220198 - Brejo_do_Piauí: 36/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220200 - Buriti_dos_Lopes: 37/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220202 - Buriti_dos_Montes: 38/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220205 - Cabeceiras_do_Piauí: 39/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220207 - Cajazeiras_do_Piauí: 40/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220208 - Cajueiro_da_Praia: 41/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220209 - Caldeirão_Grande_do_Piauí: 42/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220210 - Campinas_do_Piauí: 43/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220211 - Campo_Alegre_do_Fidalgo: 44/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220213 - Campo_Grande_do_Piauí: 45/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220217 - Campo_Largo_do_Piauí: 46/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220220 - Campo_Maior: 47/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220225 - Canavieira: 48/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220230 - Canto_do_Buriti: 49/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220240 - Capitão_de_Campos: 50/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220245 - Capitão_Gervásio_Oliveira: 51/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220250 - Caracol: 52/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220253 - Caraúbas_do_Piauí: 53/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220255 - Caridade_do_Piauí: 54/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220260 - Castelo_do_Piauí: 55/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220265 - Caxingó: 56/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220270 - Cocal: 57/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220271 - Cocal_de_Telha: 58/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220272 - Cocal_dos_Alves: 59/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220273 - Coivaras: 60/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220275 - Colônia_do_Gurguéia: 61/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220277 - Colônia_do_Piauí: 62/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220280 - Conceição_do_Canindé: 63/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220285 - Coronel_José_Dias: 64/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220290 - Corrente: 65/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220300 - Cristalândia_do_Piauí: 66/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220310 - Cristino_Castro: 67/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220320 - Curimatá: 68/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220323 - Currais: 69/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220327 - Curral_Novo_do_Piauí: 70/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220325 - Curralinhos: 71/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220330 - Demerval_Lobão: 72/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220335 - Dirceu_Arcoverde: 73/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220340 - Dom_Expedito_Lopes: 74/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220345 - Dom_Inocêncio: 75/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220342 - Domingos_Mourão: 76/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220350 - Elesbão_Veloso: 77/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220360 - Eliseu_Martins: 78/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220370 - Esperantina: 79/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220375 - Fartura_do_Piauí: 80/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220380 - Flores_do_Piauí: 81/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220385 - Floresta_do_Piauí: 82/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220390 - Floriano: 83/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220400 - Francinópolis: 84/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220410 - Francisco_Ayres: 85/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220415 - Francisco_Macedo: 86/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220420 - Francisco_Santos: 87/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220430 - Fronteiras: 88/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220435 - Geminiano: 89/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220440 - Gilbués: 90/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220450 - Guadalupe: 91/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220455 - Guaribas: 92/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220460 - Hugo_Napoleão: 93/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220465 - Ilha_Grande: 94/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220470 - Inhuma: 95/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220480 - Ipiranga_do_Piauí: 96/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220490 - Isaías_Coelho: 97/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220500 - Itainópolis: 98/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220510 - Itaueira: 99/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220515 - Jacobina_do_Piauí: 100/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220520 - Jaicós: 101/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220525 - Jardim_do_Mulato: 102/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220527 - Jatobá_do_Piauí: 103/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220530 - Jerumenha: 104/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220535 - João_Costa: 105/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220540 - Joaquim_Pires: 106/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220545 - Joca_Marques: 107/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220550 - José_de_Freitas: 108/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220551 - Juazeiro_do_Piauí: 109/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220552 - Júlio_Borges: 110/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220553 - Jurema: 111/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220555 - Lagoa_Alegre: 112/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220557 - Lagoa_de_São_Francisco: 113/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220556 - Lagoa_do_Barro_do_Piauí: 114/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220558 - Lagoa_do_Piauí: 115/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220559 - Lagoa_do_Sítio: 116/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220554 - Lagoinha_do_Piauí: 117/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220560 - Landri_Sales: 118/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220570 - Luís_Correia: 119/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220580 - Luzilândia: 120/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220585 - Madeiro: 121/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220590 - Manoel_Emídio: 122/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220595 - Marcolândia: 123/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220600 - Marcos_Parente: 124/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220605 - Massapê_do_Piauí: 125/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220610 - Matias_Olímpio: 126/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220620 - Miguel_Alves: 127/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220630 - Miguel_Leão: 128/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220635 - Milton_Brandão: 129/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220640 - Monsenhor_Gil: 130/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220650 - Monsenhor_Hipólito: 131/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220660 - Monte_Alegre_do_Piauí: 132/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220665 - Morro_Cabeça_no_Tempo: 133/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220667 - Morro_do_Chapéu_do_Piauí: 134/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220669 - Murici_dos_Portelas: 135/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220670 - Nazaré_do_Piauí: 136/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220672 - Nazária: 137/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220675 - Nossa_Senhora_de_Nazaré: 138/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220680 - Nossa_Senhora_dos_Remédios: 139/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220795 - Nova_Santa_Rita: 140/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220690 - Novo_Oriente_do_Piauí: 141/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220695 - Novo_Santo_Antônio: 142/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220700 - Oeiras: 143/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220710 - Olho_D'Água_do_Piauí: 144/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220720 - Padre_Marcos: 145/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220730 - Paes_Landim: 146/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220735 - Pajeú_do_Piauí: 147/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220740 - Palmeira_do_Piauí: 148/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220750 - Palmeirais: 149/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220755 - Paquetá: 150/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220760 - Parnaguá: 151/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220770 - Parnaíba: 152/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220775 - Passagem_Franca_do_Piauí: 153/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220777 - Patos_do_Piauí: 154/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220779 - Pau_D'Arco_do_Piauí: 155/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220780 - Paulistana: 156/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220785 - Pavussu: 157/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220790 - Pedro_II: 158/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220793 - Pedro_Laurentino: 159/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220800 - Picos: 160/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220810 - Pimenteiras: 161/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220820 - Pio_IX: 162/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220830 - Piracuruca: 163/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220840 - Piripiri: 164/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220850 - Porto: 165/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220855 - Porto_Alegre_do_Piauí: 166/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220860 - Prata_do_Piauí: 167/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220865 - Queimada_Nova: 168/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220870 - Redenção_do_Gurguéia: 169/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220880 - Regeneração: 170/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220885 - Riacho_Frio: 171/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220887 - Ribeira_do_Piauí: 172/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220890 - Ribeiro_Gonçalves: 173/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220900 - Rio_Grande_do_Piauí: 174/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220910 - Santa_Cruz_do_Piauí: 175/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220915 - Santa_Cruz_dos_Milagres: 176/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220920 - Santa_Filomena: 177/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220930 - Santa_Luz: 178/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220937 - Santa_Rosa_do_Piauí: 179/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220935 - Santana_do_Piauí: 180/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220940 - Santo_Antônio_de_Lisboa: 181/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220945 - Santo_Antônio_dos_Milagres: 182/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220950 - Santo_Inácio_do_Piauí: 183/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220955 - São_Braz_do_Piauí: 184/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220960 - São_Félix_do_Piauí: 185/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220965 - São_Francisco_de_Assis_do_Piauí: 186/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220970 - São_Francisco_do_Piauí: 187/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220975 - São_Gonçalo_do_Gurguéia: 188/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220980 - São_Gonçalo_do_Piauí: 189/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220985 - São_João_da_Canabrava: 190/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220987 - São_João_da_Fronteira: 191/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220990 - São_João_da_Serra: 192/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220995 - São_João_da_Varjota: 193/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 220997 - São_João_do_Arraial: 194/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221000 - São_João_do_Piauí: 195/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221005 - São_José_do_Divino: 196/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221010 - São_José_do_Peixe: 197/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221020 - São_José_do_Piauí: 198/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221030 - São_Julião: 199/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221035 - São_Lourenço_do_Piauí: 200/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221037 - São_Luis_do_Piauí: 201/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221038 - São_Miguel_da_Baixa_Grande: 202/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221039 - São_Miguel_do_Fidalgo: 203/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221040 - São_Miguel_do_Tapuio: 204/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221050 - São_Pedro_do_Piauí: 205/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221060 - São_Raimundo_Nonato: 206/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221062 - Sebastião_Barros: 207/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221063 - Sebastião_Leal: 208/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221065 - Sigefredo_Pacheco: 209/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221070 - Simões: 210/224
# ---------------------------------
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
#
# ...Iniciando 221080 - Simplício_Mendes: 211/224
# ---------------------------------
#
# ...Iniciando Simplício_Mendes - 201601:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 1/2016 - OK
#
# ...Iniciando Simplício_Mendes - 201602:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 2/2016 - OK
#
# ...Iniciando Simplício_Mendes - 201603:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 3/2016 - OK
#
# ...Iniciando Simplício_Mendes - 201604:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 4/2016 - OK
#
# ...Iniciando Simplício_Mendes - 201605:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 5/2016 - OK
#
# ...Iniciando Simplício_Mendes - 201606:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 6/2016 - OK
#
# ...Iniciando Simplício_Mendes - 201607:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 7/2016 - OK
#
# ...Iniciando Simplício_Mendes - 201608:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 8/2016 - OK
#
# ...Iniciando Simplício_Mendes - 201609:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 9/2016 - OK
#
# ...Iniciando Simplício_Mendes - 201610:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 10/2016 - OK
#
# ...Iniciando Simplício_Mendes - 201611:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 11/2016 - OK
#
# ...Iniciando Simplício_Mendes - 201612:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 12/2016 - OK
#
# ...Iniciando Simplício_Mendes - 201701:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 1/2017 - OK
#
# ...Iniciando Simplício_Mendes - 201702:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 2/2017 - OK
#
# ...Iniciando Simplício_Mendes - 201703:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 3/2017 - OK
#
# ...Iniciando Simplício_Mendes - 201704:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 4/2017 - OK
#
# ...Iniciando Simplício_Mendes - 201705:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 5/2017 - OK
#
# ...Iniciando Simplício_Mendes - 201706:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 6/2017 - OK
#
# ...Iniciando Simplício_Mendes - 201707:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 7/2017 - OK
#
# ...Iniciando Simplício_Mendes - 201708:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 8/2017 - OK
#
# ...Iniciando Simplício_Mendes - 201709:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 9/2017 - OK
#
# ...Iniciando Simplício_Mendes - 201710:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 10/2017 - OK
#
# ...Iniciando Simplício_Mendes - 201711:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 11/2017 - OK
#
# ...Iniciando Simplício_Mendes - 201712:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 12/2017 - OK
#
# ...Iniciando Simplício_Mendes - 201801:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 1/2018 - OK
#
# ...Iniciando Simplício_Mendes - 201802:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 2/2018 - OK
#
# ...Iniciando Simplício_Mendes - 201803:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 3/2018 - OK
#
# ...Iniciando Simplício_Mendes - 201804:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Simplício_Mendes - 4/2018 - OK
#
# ...Iniciando Simplício_Mendes - 201805:
# > Carregando pagina
# ...
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 4/2019 - OK
#
# ...Iniciando Wall_Ferraz - 201905:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 5/2019 - OK
#
# ...Iniciando Wall_Ferraz - 201906:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 6/2019 - OK
#
# ...Iniciando Wall_Ferraz - 201907:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 7/2019 - OK
#
# ...Iniciando Wall_Ferraz - 201908:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 8/2019 - OK
#
# ...Iniciando Wall_Ferraz - 201909:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 9/2019 - OK
#
# ...Iniciando Wall_Ferraz - 201910:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 10/2019 - OK
#
# ...Iniciando Wall_Ferraz - 201911:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 11/2019 - OK
#
# ...Iniciando Wall_Ferraz - 201912:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 12/2019 - OK
#
# ...Iniciando Wall_Ferraz - 202001:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 1/2020 - OK
#
# ...Iniciando Wall_Ferraz - 202002:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 2/2020 - OK
#
# ...Iniciando Wall_Ferraz - 202003:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 3/2020 - OK
#
# ...Iniciando Wall_Ferraz - 202004:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 4/2020 - OK
#
# ...Iniciando Wall_Ferraz - 202005:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 5/2020 - OK
#
# ...Iniciando Wall_Ferraz - 202006:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 6/2020 - OK
#
# ...Iniciando Wall_Ferraz - 202007:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 7/2020 - OK
#
# ...Iniciando Wall_Ferraz - 202008:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 8/2020 - OK
#
# ...Iniciando Wall_Ferraz - 202009:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 9/2020 - OK
#
# ...Iniciando Wall_Ferraz - 202010:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 10/2020 - OK
#
# ...Iniciando Wall_Ferraz - 202011:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 11/2020 - OK
#
# ...Iniciando Wall_Ferraz - 202012:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 12/2020 - OK
#
# ...Iniciando Wall_Ferraz - 202101:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 1/2021 - OK
#
# ...Iniciando Wall_Ferraz - 202102:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 2/2021 - OK
#
# ...Iniciando Wall_Ferraz - 202103:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 3/2021 - OK
#
# ...Iniciando Wall_Ferraz - 202104:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 4/2021 - OK
#
# ...Iniciando Wall_Ferraz - 202105:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 5/2021 - OK
#
# ...Iniciando Wall_Ferraz - 202106:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 6/2021 - OK
#
# ...Iniciando Wall_Ferraz - 202107:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 7/2021 - OK
#
# ...Iniciando Wall_Ferraz - 202108:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 8/2021 - OK
#
# ...Iniciando Wall_Ferraz - 202109:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 9/2021 - OK
#
# ...Iniciando Wall_Ferraz - 202110:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 10/2021 - OK
#
# ...Iniciando Wall_Ferraz - 202111:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 11/2021 - OK
#
# ...Iniciando Wall_Ferraz - 202112:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 12/2021 - OK
#
# ...Iniciando Wall_Ferraz - 202201:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 1/2022 - OK
#
# ...Iniciando Wall_Ferraz - 202202:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 2/2022 - OK
#
# ...Iniciando Wall_Ferraz - 202203:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 3/2022 - OK
#
# ...Iniciando Wall_Ferraz - 202204:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 4/2022 - OK
#
# ...Iniciando Wall_Ferraz - 202205:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 5/2022 - OK
#
# ...Iniciando Wall_Ferraz - 202206:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 6/2022 - OK
#
# ...Iniciando Wall_Ferraz - 202207:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 7/2022 - OK
#
# ...Iniciando Wall_Ferraz - 202208:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 8/2022 - OK
#
# ...Iniciando Wall_Ferraz - 202209:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 9/2022 - OK
#
# ...Iniciando Wall_Ferraz - 202210:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 10/2022 - OK
#
# ...Iniciando Wall_Ferraz - 202211:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 11/2022 - OK
#
# ...Iniciando Wall_Ferraz - 202212:
# > Carregando pagina
# >> Pagina carregada
# > Explorando a pagina
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >> Carregando informações
# >>> Merge com dados do municipio
# >>> Identificando total populacional do periodo
# >>> Adicionando à planilha completa
# Dataset: Wall_Ferraz - 12/2022 - OK
# ---------------------------------
# >> Salvando dados
# >>> Dados salvos
#
# ...Limpando terminal
# ... Finalizando
# <><><><><><><><><><><><><><><><><><><>
# !!! Finalizado !!!
